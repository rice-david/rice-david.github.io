# %%
import numpy as np
import colour
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
sd = colour.sd_gaussian(500, 1, method="FWHM") #maybe my source is a green with a single source. 

sd.shape

colour.plotting.plot_single_sd(sd)


#Can take this and convert to a 
favorite_color = (colour.sd_to_XYZ(sd)) #from

# %%
favorite_color
# Out:
# array([  8.16317196,  26.92997348,  32.28183266])

# %%
#colour.plotting.ColourSwatch(favorite_color, name="My favorite Color")
import matplotlib.pyplot as plt

swatch = colour.plotting.ColourSwatch((favorite_color))
swatch2 = colour.plotting.ColourSwatch((favorite_color))
colour.plotting.plot_multi_colour_swatches([swatch])
#colour.plotting.plot_multi_colour_swatches([swatch])
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
favorite_color
# Out:
# array([  8.16317196,  26.92997348,  32.28183266])

# %%
RGB_1 = colour.plotting.ColourSwatch((0.45293517, 0.31732158, 0.26414773))
RGB_2 = colour.plotting.ColourSwatch((0.77875824, 0.57726450, 0.50453169))
colour.plotting.plot_multi_colour_swatches([favorite_color])
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)
